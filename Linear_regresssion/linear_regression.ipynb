# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])

print(f"x_train = {x_train}")
print(f"y_train  : {y_train}")
# Out:
# x_train = [1. 2.]
# y_train  : [300. 500.]

# %%
# m is the number of training examples 

print(f"x_train.shape : {x_train.shape}")
m = x_train.shape[0]

print(f"Number of training examples is : {m}")

# one can also use len to denote the number of trainings data 

m = len(x_train)
print(f"Number of training examples is : {m}")
# Out:
# x_train.shape : (2,)
# Number of training examples is : 2
# Number of training examples is : 2

# %%
## Training examples x_i , y_i 

# let's say that we want , a training example at a specific position  


i = 0 

x_i = x_train[i]
y_i = y_train[i]
print(f"training set at position 0 is x^({i}) , y^({i}) = ({x_i}) , ({y_i})")
# Out:
# training set at position 0 is x^(0) , y^(0) = (1.0) , (300.0)

# %% [markdown]
# ## Plotting the data

# %%
# plot the data 

plt.scatter(x_train, y_train,marker='x' , c='r')
plt.title("Housing price ")
plt.ylabel('Housing price ')
plt.xlabel('SQFT (of the house )')
plt.show()

# %%
w = 100, 
b =  100
def linearRegressionFunction (x ,w , b ):
    """ 
    Computes the prediction of a linear model Args: 

    x (ndarray (m, )) : Data , m examples 
    w , b(scalar ) : model parameters 
    
    
    """
    
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w*x[i] +b 
    return f_wb

# %%
w = 100 
b = 100 

tm_f_wb = linearRegressionFunction(x_train , w , b)
# plot our model prediction 


plt.plot(x_train , tm_f_wb, c ='b',label='Our prediction')

# plot the data points 
plt.scatter(x_train, y_train, marker='x', c ='r', label ='Actual values ')

# sert the title 

plt.title('Housing prices ')

# Set the y-axis label 

plt.ylabel('Price (in 1000s of dollars )')

# set the x-axis label 
plt.xlabel('SIZE (1000 sqft)')
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
def linearRegressionFunction(x, w , b):
    m = x.shape[0]
    f_wb = np.zeros(m)

    for i in range(m):
        f_wb[i] = w*x[i] + b 

    return f_wb

# %%
w = 100
b = 100

predicted_values = linearRegressionFunction(x_train , w , b)

print(predicted_values)
# Out:
# [200. 300.]

# %%
# plot our prediction 

plt.plot(x_train , predicted_values , label='Our model prediction', c='b')
plt.scatter(x_train, y_train, label='actual values', c='r')
plt.xlabel('sqft of the house ')
plt.ylabel('1000 s in dollar ')
plt.title('Housing price ')
# Out:
# Text(0.5, 1.0, 'Housing price ')
